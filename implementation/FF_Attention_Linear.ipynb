# %% [markdown]
# ### Mount GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Remove pre-existing logs

# %%
# !rm -r /content/linear/ /content/attention/

# %% [markdown]
# ### Import Libraries

# %%
import logging
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
import os
import sys
import time
import torch
import torch.nn as nn

from sklearn.metrics import accuracy_score, f1_score
from tqdm import tqdm
from torch.optim import Adam
from torchvision.datasets import MNIST
from torchvision.datasets import FashionMNIST
from torchvision.datasets import CIFAR10
from torchvision.datasets import CIFAR100
from torchvision.datasets import SVHN
from torchvision.transforms import Compose, ToTensor, Normalize, Lambda
from torch.utils.data import DataLoader
from torch.utils.data.dataset import TensorDataset

# %% [markdown]
# ### Add GPU

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Choose FF Type and Dataset

# %%
ff_type = 'linear'
# ff_type = 'attention'

dataset = 'MNIST'
# dataset = 'FashionMNIST'
# dataset = 'CIFAR10'
# dataset = 'CIFAR100'
# dataset = 'SVHN'

# %% [markdown]
# ### Create Log Directories

# %%
if not os.path.exists(ff_type):
  os.mkdir(ff_type)
        
path = os.path.join(ff_type, dataset)
if not os.path.exists(path):
  os.mkdir(path)

# %% [markdown]
# ### Define Nvidia SMI logging to be run as a background process

# %%
def start_logging(logger):
    print("******* nvidia-smi logging started *******")
    while True:
        nvidia_smi_entry = os.popen("nvidia-smi --query-gpu=timestamp,temperature.gpu,utilization.gpu,utilization.memory,memory.used,memory.free,memory.total,power.draw --format=csv | sed -n '2 p'").read()
        logger.info(nvidia_smi_entry)
    print("******* nvidia-smi logging ended *******")

# %% [markdown]
# ### Setup Loggers

# %%
formatter = logging.Formatter('%(message)s')
def setup_logger(name, log_file, level=logging.INFO):
    """To setup as many loggers as you want"""

    handler = logging.FileHandler(log_file)
    handler.setFormatter(formatter)

    logger = logging.getLogger(name)
    logger.setLevel(level)
    logger.addHandler(handler)
    
    return logger

# %% [markdown]
# ### Initialize Loggers

# %%
# nvidia smi logger

logger_nvidia_smi = setup_logger(path+"_logger_nvidia_smi", os.path.join(path, "nvidia_smi.csv"))
system_logger = multiprocessing.Process(target=start_logging, args=[logger_nvidia_smi])

# layer loggers

logger_layer_ff = setup_logger(path+"_logger_layer_ff", os.path.join(path, "layer_ff.csv"))
logger_layer_ff.info('layer_num,layertime_ms')

# e2e loggers

logger_e2e_ff = setup_logger(path+"_logger_e2e_ff", os.path.join(path, "e2e_ff.csv"))
logger_e2e_ff.info('e2etime_ms')

# linear ff loggers

logger_gpu_compute_linear_ff = setup_logger(path+"_logger_gpu_compute_linear_ff", os.path.join(path, "gpu_compute_linear_ff.csv"))
logger_gpu_compute_linear_ff.info('epoch,gpucomputetime_ms')

logger_epoch_linear_ff = setup_logger(path+"_logger_epoch_linear_ff", os.path.join(path, "epoch_linear_ff.csv"))
logger_epoch_linear_ff.info('epoch_num,epochtime_ms')

# attention ff loggers

logger_gpu_compute_attention_ff = setup_logger(path+"_logger_gpu_compute_attention_ff", os.path.join(path, "gpu_compute_attention_ff.csv"))
logger_gpu_compute_attention_ff.info('epoch,gpucomputetime_ms')

logger_epoch_attention_ff = setup_logger(path+"_logger_epoch_attention_ff", os.path.join(path, "epoch_attention_ff.csv"))
logger_epoch_attention_ff.info('epoch_num,epochtime_ms')
# Out:
# INFO:linear/MNIST_logger_layer_ff:layer_num,layertime_ms
# INFO:linear/MNIST_logger_e2e_ff:e2etime_ms
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:epoch,gpucomputetime_ms
# INFO:linear/MNIST_logger_epoch_linear_ff:epoch_num,epochtime_ms
# INFO:linear/MNIST_logger_gpu_compute_attention_ff:epoch,gpucomputetime_ms
# INFO:linear/MNIST_logger_epoch_attention_ff:epoch_num,epochtime_ms

# %% [markdown]
# ### Initialize Timers

# %%
# layer ff timers

layer_ff_start = torch.cuda.Event(enable_timing=True)
layer_ff_end = torch.cuda.Event(enable_timing=True)

# e2e ff timers

e2e_ff_start = torch.cuda.Event(enable_timing=True)
e2e_ff_end = torch.cuda.Event(enable_timing=True)

# linear ff timers

gpu_compute_linear_ff_start = torch.cuda.Event(enable_timing=True)
gpu_compute_linear_ff_end = torch.cuda.Event(enable_timing=True)
epoch_linear_ff_start = torch.cuda.Event(enable_timing=True)
epoch_linear_ff_end = torch.cuda.Event(enable_timing=True)

# attention ff timers

gpu_compute_attention_ff_start = torch.cuda.Event(enable_timing=True)
gpu_compute_attention_ff_end = torch.cuda.Event(enable_timing=True)
epoch_attention_ff_start = torch.cuda.Event(enable_timing=True)
epoch_attention_ff_end = torch.cuda.Event(enable_timing=True)
e2e_attention_ff_start = torch.cuda.Event(enable_timing=True)
e2e_attention_ff_end = torch.cuda.Event(enable_timing=True)

# %% [markdown]
# ### Define Overlay

# %%
def overlay_y_on_x(x, y, num_labels):
    """Replace the first num_label pixels of data [x] with one-hot-encoded label [y]
    """
    x_ = x.clone()
    x_[:, :num_labels] *= 0.0
    x_[range(x.shape[0]), y] = x.max()
    return x_

# %% [markdown]
# ### Define Attention Layer

# %%
class Attention_layer(nn.Module):

  def __init__(self, input_size: tuple, output_size: int, patch_size: int):
    """
      input_size: n_h, n_w, n_c
      output_size: int
      patch_size: int
    """
    super().__init__()
    self.input_size = input_size
    self.patch_size = patch_size
    self.output_size = output_size

    n_h, n_w, n_c = input_size
    patch_dim = n_h // patch_size
    num_patches = patch_dim ** 2 
    self.patch_embedding = nn.Conv2d(n_c, 64, kernel_size=patch_size, stride=patch_size, device=device)

    for param in self.patch_embedding.parameters():
      param.requires_grad = False

    self.self_attn = nn.MultiheadAttention(64, 8, device=device)
    self.fc1 = nn.Linear(64, output_size, device=device)
    self.lrelu = nn.ReLU() #nn.LeakyReLU()

  def __normalize(self, x):
    x_shape = x.shape
    x = x.reshape(x_shape[0], -1)
    x = x / (x.norm(2, 1, keepdim=True) + 1e-4)
    x = x.reshape(x_shape)
    return x

  def __reshape(self, x):
    x = x.reshape(x.size(0), self.input_size[2], self.input_size[0], self.input_size[1])
    return x

  def forward(self, x):
    x = self.__normalize(x) 
    x = self.__reshape(x) # (batch_size, channel_size, height, width)
    x = self.patch_embedding(x) # (batch_size, 64, patch_dim, patch_dim)
    x = x.flatten(2).transpose(1, 2) # (batch_size, num_patches, 64)

    x = x.transpose(0, 1)  # (num_patches, batch_size, 64)
    x, _ = self.self_attn(x, x, x)
    x = x.mean(dim=0) # (batch_size, 64)


    x = self.__normalize(x)
    x = self.fc1(x)

    x = self.lrelu(x)

    return x
  
  def train_ff(self, train_loader, epoch_range, batch_size, lr=0.03, threshold=2.0):
    optimizer = torch.optim.Adam(self.parameters(), lr=1e-4)
    next_pos = []
    next_neg = []
    next_label = []
    for e in epoch_range:
      epoch_attention_ff_start.record() # start recording epoch time
      for (x_pos, x_neg, label) in train_loader:
        gpu_compute_attention_ff_start.record() # start recording gpu compute time
        x_pos = x_pos.to(device)
        x_neg = x_neg.to(device)
        g_pos = self.forward(x_pos).pow(2).mean(dim=1)
        g_neg = self.forward(x_neg).pow(2).mean(dim=1)

        loss = torch.log(1 + torch.exp(
            torch.cat([
                threshold - g_pos,
                g_neg - threshold
            ])
        )).mean()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        x_pos = x_pos.detach()
        x_neg = x_neg.detach()
        gpu_compute_attention_ff_end.record() # end recording gpu compute time
        torch.cuda.synchronize()
        logger_gpu_compute_attention_ff.info(str(e)+","+str(gpu_compute_attention_ff_start.elapsed_time(gpu_compute_attention_ff_end))) # log gpu compute time
      epoch_attention_ff_end.record() # end recording epoch time
      torch.cuda.synchronize()
      logger_epoch_attention_ff.info(str(e)+","+str(epoch_attention_ff_start.elapsed_time(epoch_attention_ff_end))) # log epoch time

    for (x_pos, x_neg, label) in train_loader:
      x_pos = x_pos.to(device)
      x_neg = x_neg.to(device)    
      x_pos_next = self.forward(x_pos).detach()
      x_neg_next = self.forward(x_neg).detach()
      next_pos.append(x_pos_next)
      next_neg.append(x_neg_next)
      next_label.append(label)
      x_pos = x_pos.detach()
      x_neg = x_neg.detach()
    
    next_pos = torch.cat(next_pos, dim=0)
    next_neg = torch.cat(next_neg, dim=0)
    next_label = torch.cat(next_label, dim=0)

    return DataLoader(TensorDataset(
        next_pos,
        next_neg,
        next_label
    ), batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### Define Linear Layer

# %%
class Linear_layer(nn.Linear):

  def __init__(self, in_features, out_features,
                 bias=True, device=None, dtype=None):
    super().__init__(in_features, out_features, bias, device, dtype)
    self.relu = torch.nn.ReLU()

  def forward(self, x):
      x_direction = x / (x.norm(2, 1, keepdim=True) + 1e-4)
      return self.relu(
          torch.mm(x_direction, self.weight.T) +
          self.bias.unsqueeze(0))

  def train_ff(self, train_loader, epoch_range, batch_size, lr=0.03, threshold=2.0):
    
    optimizer = torch.optim.Adam(self.parameters(), lr=lr)
    next_pos = []
    next_neg = []
    next_label = []

    for i in epoch_range:
      epoch_linear_ff_start.record() # start recording epoch time
      for (x_pos, x_neg, label) in train_loader:
        gpu_compute_linear_ff_start.record() # start recording gpu compute time
        x_pos = x_pos.to(device)
        x_neg = x_neg.to(device)
        g_pos = self.forward(x_pos).pow(2).mean(1)
        g_neg = self.forward(x_neg).pow(2).mean(1)
        loss = torch.log(1 + torch.exp(torch.cat([
            -g_pos + threshold,
            g_neg - threshold]))).mean()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        x_pos = x_pos.detach()
        x_neg = x_neg.detach()
        gpu_compute_linear_ff_end.record() # end recording gpu compute time
        torch.cuda.synchronize()
        logger_gpu_compute_linear_ff.info(str(i)+","+str(gpu_compute_linear_ff_start.elapsed_time(gpu_compute_linear_ff_end))) # log gpu compute time
      epoch_linear_ff_end.record() # end recording epoch time
      torch.cuda.synchronize()
      logger_epoch_linear_ff.info(str(i)+","+str(epoch_linear_ff_start.elapsed_time(epoch_linear_ff_end))) # log epoch time

    for (x_pos, x_neg, label) in train_loader:
      x_pos = x_pos.to(device)
      x_neg = x_neg.to(device)  
      x_pos_next = self.forward(x_pos).detach()
      x_neg_next = self.forward(x_neg).detach()
      next_pos.append(x_pos_next)
      next_neg.append(x_neg_next)
      next_label.append(label)
      x_pos = x_pos.detach()
      x_neg = x_neg.detach()
  
    next_pos = torch.cat(next_pos, dim=0)
    next_neg = torch.cat(next_neg, dim=0)
    next_label = torch.cat(next_label, dim=0)
    
    return DataLoader(TensorDataset(
        next_pos,
        next_neg,
        next_label
    ), batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### Define Net

# %%
class Net(nn.Module):

  def __init__(self, layers, num_labels):
    super().__init__()
    self.layers = layers
    self.num_labels = num_labels

  def train_ff(self, train_loader, epochs=1000, **kwargs):
    cur_train_loader = train_loader
    batch_size = train_loader.batch_size
    for i, layer in enumerate(self.layers):
      
      is_large_batch = len(cur_train_loader) >= 5
      print(f"Training layer: {i+1} ... tqdm: {'loader' if not is_large_batch else 'epoch'}")

      cur_train_loader = tqdm(cur_train_loader) if not is_large_batch else cur_train_loader
      epoch_range = tqdm(range(epochs)) if is_large_batch else range(epochs)
      
      layer_ff_start.record() # start recording layer train time
      cur_train_loader = layer.train_ff(cur_train_loader, epoch_range=epoch_range, batch_size=batch_size, **kwargs) # train layer
      layer_ff_end.record() # end recording layer train time
      torch.cuda.synchronize()
      logger_layer_ff.info(str(i)+","+str(layer_ff_start.elapsed_time(layer_ff_end))) # log layer train time

  def forward(self, x):
    for layer in self.layers:
      x = layer(x)
    return x

  def predict_ff(self, data_loader):

    def predict(layers, x, num_labels):
      goodness_per_label = []
      for label in range(num_labels):
          h = overlay_y_on_x(x, label, num_labels)
          goodness = []
          for i, layer in enumerate(layers):
              h = layer(h)
              # if i==0:
                # continue
              goodness += [h.pow(2).mean(1)]
          goodness_per_label += [sum(goodness).unsqueeze(1)]
      goodness_per_label = torch.cat(goodness_per_label, 1)
      return goodness_per_label.argmax(1)
    
    preds = []
    labels = []
    for x, label in data_loader:
      x = x.to(device)
      preds.append(predict(self.layers, x, self.num_labels))
      labels.append(label)

    preds = torch.cat(preds, 0)
    labels = torch.cat(labels, 0)
    return preds.cpu(), labels.cpu()

  def predict_bp(self, data_loader):
    preds = []
    labels = []
    for input, label in data_loader:
      input = input.to(device)
      pred = self.forward(input)
      preds.append(pred.argmax(1))
      labels.append(label)
    preds = torch.cat(preds, 0)
    labels = torch.cat(labels,0)
    return preds.cpu(), labels.cpu()

# %% [markdown]
# ### Define MNIST Dataset

# %%
def MNIST_dataset():
  transform = Compose([
        ToTensor(),
        Normalize((0.1307,), (0.3081,)),
        Lambda(lambda x: torch.flatten(x))])
  train_data = MNIST('./data/MNIST/', train=True,
              download=True,
              transform=transform)
  test_data = MNIST('./data/MNIST/', train=False,
              download=True,
              transform=transform)
  return train_data, test_data

# %% [markdown]
# ### Define Fashion MNIST Dataset

# %%
def FashionMNIST_dataset():

    transform = Compose([
        ToTensor(),
        Normalize((0.1307,), (0.3081,)),
        Lambda(lambda x: torch.flatten(x))])

    train_loader = FashionMNIST('./data/FashionMNIST', train=True,
              download=True,
              transform=transform)

    test_loader = FashionMNIST('./data/FashionMNIST', train=False,
              download=True,
              transform=transform)

    return train_loader, test_loader

# %% [markdown]
# ### Define CIFAR10 Dataset

# %%
def CIFAR10_dataset():

    transform = Compose([
        ToTensor(),
        Normalize((0.4914, 0.4822, 0.4465), (0.4914, 0.4822, 0.4465)),
        Lambda(lambda x: torch.flatten(x))])

    train_loader = CIFAR10('./data/CIFAR10', train=True,
              download=True,
              transform=transform)

    test_loader = CIFAR10('./data/CIFAR10', train=False,
              download=True,
              transform=transform)

    return train_loader, test_loader

# %% [markdown]
# ### Define CIFAR100 Dataset

# %%
def CIFAR100_dataset():

    transform = Compose([
        ToTensor(),
        Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        Lambda(lambda x: torch.flatten(x))])

    train_loader = CIFAR100('./data/CIFAR100', train=True,
              download=True,
              transform=transform)

    test_loader = CIFAR100('./data/CIFAR100', train=False,
              download=True,
              transform=transform)

    return train_loader, test_loader

# %% [markdown]
# ### Define SVHN Dataset

# %%
def SVHN_dataset():

    transform = Compose([
        ToTensor(),
        Normalize((0.4377, 0.4438, 0.4728), (0.1980, 0.2010, 0.1970)),
        Lambda(lambda x: torch.flatten(x))])

    train_loader = SVHN('./data/SVHN', split='train',
              download=True,
              transform=transform)

    test_loader = SVHN('./data/SVHN', split='test',
              download=True,
              transform=transform)

    return train_loader, test_loader

# %% [markdown]
# ### Define Train and Test Sets

# %%
def create_ff_train_dataset(train_loader, num_labels):
  pos_set = []
  neg_set = []
  label_set = []
  for input, label in tqdm(train_loader):
    x_pos = overlay_y_on_x(input, label, num_labels)
    rnd = torch.randperm(input.size(0))
    x_neg = overlay_y_on_x(input, label[rnd], num_labels)
    pos_set.append(x_pos)
    neg_set.append(x_neg)
    label_set.append(label)
  pos_set = torch.cat(pos_set, 0)
  neg_set = torch.cat(neg_set, 0)
  label_set = torch.cat(label_set, 0)
  return TensorDataset(pos_set, neg_set, label_set)

def create_ff_val_dataset(val_loader):
  inputs = []
  labels = []

  for input, label in tqdm(val_loader):
    inputs.append(input)
    labels.append(label)
  inputs = torch.cat(inputs, 0)
  labels = torch.cat(labels, 0)
  return TensorDataset(inputs, labels)

# %% [markdown]
# ### Set Random Seed

# %%
torch.manual_seed(1234)

# %% [markdown]
# ### Download Dataset

# %%
if dataset == 'MNIST':
  train_data, test_data = MNIST_dataset()
elif dataset == 'FashionMNIST':
  train_data, test_data = FashionMNIST_dataset()
elif dataset == 'CIFAR10': 
  train_data, test_data = CIFAR10_dataset()
elif dataset == 'CIFAR100':
  train_data, test_data = CIFAR100_dataset()
elif dataset == 'SVHN':
  train_data, test_data = SVHN_dataset()
else:
  print('Invalid dataset')
  exit()
print(train_data, test_data)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 29270198.02it/s]
# Extracting ./data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 8777948.83it/s]
# Extracting ./data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 7790016.99it/s]
# Extracting ./data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 18676988.99it/s]
# Extracting ./data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/MNIST/raw
#
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data/MNIST/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#                Lambda()
#            ) Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data/MNIST/
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#                Lambda()
#            )

# %% [markdown]
# ### Create Train and Test Sets

# %%
train_dataset = create_ff_train_dataset(DataLoader(train_data, batch_size=1024, shuffle=False), 10)
test_dataset = create_ff_val_dataset(DataLoader(test_data, batch_size=1024, shuffle=False))
# Out:
# 100%|██████████| 59/59 [00:20<00:00,  2.91it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.68it/s]

# %% [markdown]
# ### Define Net

# %%
if ff_type == 'linear':
  
  layers = [
    Linear_layer(28*28, 2000, device=device),
    # Linear_layer(32*32*3, 2000, device=device),
    Linear_layer(2000, 2000, device=device),
    Linear_layer(2000, 2000, device=device),
    Linear_layer(2000, 2000, device=device)
  ]

elif ff_type == 'attention':
  
    layers = [
    Attention_layer((28, 28, 1), 2000, 4),
    # Attention_layer((32, 32, 3), 2000, 4),
    Linear_layer(2000, 2000, device=device),
    Linear_layer(2000, 2000, device=device),
    Linear_layer(2000, 2000, device=device)
  ]

else:
  print('Invalid net type')
  exit()

net = Net(layers, 10)

# %%
layers
# Out:
# [Linear_layer(
#    in_features=784, out_features=2000, bias=True
#    (relu): ReLU()
#  ),
#  Linear_layer(
#    in_features=2000, out_features=2000, bias=True
#    (relu): ReLU()
#  ),
#  Linear_layer(
#    in_features=2000, out_features=2000, bias=True
#    (relu): ReLU()
#  ),
#  Linear_layer(
#    in_features=2000, out_features=2000, bias=True
#    (relu): ReLU()
#  )]

# %% [markdown]
# ### Start Nvidia SMI logging

# %%
# system_logger.start()

# %% [markdown]
# ### Train Net

# %%
logger_e2e_ff.setLevel(logging.DEBUG)
logger_epoch_attention_ff.setLevel(logging.DEBUG)

# %%
e2e_ff_start.record() # start recording e2e train time
net.train_ff(DataLoader(train_dataset, batch_size=512, shuffle=True), epochs=60, lr=0.02, threshold=15)
e2e_ff_end.record() # end recording e2e train time
torch.cuda.synchronize()
logger_e2e_ff.info(str(e2e_ff_start.elapsed_time(e2e_ff_end))) # log e2e train time
# Out:
# Training layer: 1 ... tqdm: epoch
# Streaming output truncated to the last 5000 lines.
#  30%|███       | 18/60 [00:31<01:17,  1.85s/it]INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3554558753967285
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.898752212524414
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,6.299551963806152
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.4358720779418945
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.453760147094727
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.490880012512207
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.527103900909424
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.375999927520752
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.356800079345703
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.490079879760742
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.376031875610352
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.334688186645508
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.406400203704834
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.489920139312744
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3969597816467285
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.683199882507324
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.396416187286377
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.349823951721191
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.738175868988037
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.402624130249023
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.544447898864746
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.614016056060791
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.342368125915527
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.382143974304199
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.5041279792785645
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.378911972045898
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.36572790145874
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.400991916656494
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3718719482421875
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.367807865142822
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.755040168762207
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.451776027679443
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.521823883056641
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3679680824279785
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.336575984954834
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.362624168395996
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.361536026000977
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.429567813873291
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.326303958892822
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,6.970111846923828
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.4268798828125
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.322751998901367
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.399168014526367
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.400576114654541
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.576608180999756
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3291521072387695
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.4620161056518555
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.4312639236450195
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.323840141296387
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.471263885498047
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.500927925109863
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.412831783294678
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.6671037673950195
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.345280170440674
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3373122215271
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.396736145019531
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,6.492159843444824
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.416959762573242
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.354464054107666
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.40451192855835
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.691391944885254
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3937602043151855
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.343584060668945
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.400928020477295
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.449471950531006
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.334911823272705
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.5668158531188965
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.361311912536621
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.5562238693237305
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.426144123077393
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.339776039123535
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.349823951721191
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.367519855499268
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.357056140899658
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.933504104614258
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.388256072998047
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.363423824310303
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,6.646080017089844
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.498847961425781
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.394432067871094
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.553664207458496
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.398367881774902
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3370561599731445
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.337120056152344
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.37007999420166
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.4073920249938965
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.328703880310059
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.420544147491455
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.407296180725098
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.374591827392578
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.368768215179443
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.381408214569092
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.487199783325195
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.356736183166504
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.693535804748535
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.425151824951172
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.381343841552734
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.4431681632995605
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.457024097442627
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.386176109313965
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.344511985778809
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.396448135375977
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.392576217651367
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.47219181060791
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.528160095214844
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.433375835418701
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.487040042877197
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3496317863464355
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.329311847686768
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.58892822265625
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5.3763837814331055
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:18,5
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.498976230621338
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.519455909729004
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.507872104644775
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.501344203948975
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.596447944641113
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.519999980926514
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.508607864379883
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.598656177520752
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.568160057067871
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.58025598526001
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.579904079437256
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.564479827880859
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.594912052154541
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.565728187561035
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.563807964324951
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.785247802734375
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.578176021575928
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.950272083282471
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.040768146514893
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.606815814971924
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.569983959197998
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.454751968383789
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.5951361656188965
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.572127819061279
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8575358390808105
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.74015998840332
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,8.663871765136719
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.727807998657227
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.719456195831299
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.741919994354248
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.718592166900635
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.231840133666992
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.877151966094971
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.879231929779053
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.844448089599609
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.848447799682617
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.850592136383057
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.871776103973389
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.865536212921143
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.864895820617676
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.87113618850708
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.846464157104492
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.835072040557861
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8963518142700195
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.873119831085205
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8895039558410645
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8751678466796875
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.870304107666016
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8730878829956055
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8685760498046875
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.843935966491699
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.959136009216309
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.903808116912842
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.871456146240234
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.1372480392456055
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.892543792724609
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.840191841125488
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8587517738342285
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.853119850158691
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8887038230896
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.643648147583008
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.875455856323242
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.560031890869141
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.866943836212158
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8687357902526855
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8751678466796875
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.93017578125
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.898240089416504
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.906047821044922
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.883359909057617
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.852928161621094
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.855711936950684
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.88259220123291
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.864384174346924
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.8157758712768555
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.772704124450684
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.70300817489624
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,6.751711845397949
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,7.882719993591309
# INFO:linear/MNIST_logger_gpu_compute_linear_ff:59,3.60646390914917
# INFO:linear/MNIST_logger_epoch_linear_ff:59,2422.02001953125
# 100%|██████████| 60/60 [01:58<00:00,  1.98s/it]
# INFO:linear/MNIST_logger_layer_ff:3,120053.046875
# INFO:linear/MNIST_logger_e2e_ff:473068.6875

# %% [markdown]
# ### Check Performance of Net

# %%
pred, true = net.predict_ff(DataLoader(test_dataset, batch_size=512, shuffle=False))
accuracy_score(true, pred)
f1_score(true, pred, average=None)
# Out:
# array([0.11929275, 0.15569002, 0.09788268, 0.06449975, 0.0650042 ,
#        0.03541473, 0.02707137, 0.02406739, 0.02703963, 0.02359882])

# %% [markdown]
# ### Stop Nvidia SMI logging

# %%
system_logger.terminate()

# %% [markdown]
# ### Create .zip files of logs

# %%
# !zip -r /content/linear.zip /content/linear/
# !zip -r /content/attention.zip /content/attention/
# Out:
# updating: content/linear/ (stored 0%)
# updating: content/linear/FashionMNIST/ (stored 0%)
# updating: content/linear/FashionMNIST/gpu_compute_attention_ff.csv (deflated 40%)
# updating: content/linear/FashionMNIST/epoch_linear_ff.csv (deflated 59%)
# updating: content/linear/FashionMNIST/nvidia_smi.csv (deflated 89%)
# updating: content/linear/FashionMNIST/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/linear/FashionMNIST/layer_ff.csv (deflated 27%)
# updating: content/linear/FashionMNIST/epoch_attention_ff.csv (deflated 43%)
# updating: content/linear/FashionMNIST/e2e_ff.csv (deflated 23%)
# updating: content/linear/CIFAR10/ (stored 0%)
# updating: content/linear/CIFAR10/gpu_compute_attention_ff.csv (stored 0%)
# updating: content/linear/CIFAR10/epoch_linear_ff.csv (deflated 58%)
# updating: content/linear/CIFAR10/nvidia_smi.csv (deflated 88%)
# updating: content/linear/CIFAR10/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/linear/CIFAR10/layer_ff.csv (deflated 11%)
# updating: content/linear/CIFAR10/epoch_attention_ff.csv (deflated 4%)
# updating: content/linear/CIFAR10/e2e_ff.csv (stored 0%)
# updating: content/linear/CIFAR100/ (stored 0%)
# updating: content/linear/CIFAR100/gpu_compute_attention_ff.csv (stored 0%)
# updating: content/linear/CIFAR100/epoch_linear_ff.csv (deflated 58%)
# updating: content/linear/CIFAR100/nvidia_smi.csv (deflated 88%)
# updating: content/linear/CIFAR100/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/linear/CIFAR100/layer_ff.csv (deflated 11%)
# updating: content/linear/CIFAR100/epoch_attention_ff.csv (deflated 4%)
# updating: content/linear/CIFAR100/e2e_ff.csv (stored 0%)
# updating: content/linear/SVHN/ (stored 0%)
# updating: content/linear/SVHN/gpu_compute_attention_ff.csv (stored 0%)
# updating: content/linear/SVHN/epoch_linear_ff.csv (deflated 58%)
# updating: content/linear/SVHN/nvidia_smi.csv (deflated 87%)
# updating: content/linear/SVHN/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/linear/SVHN/layer_ff.csv (deflated 10%)
# updating: content/linear/SVHN/epoch_attention_ff.csv (deflated 4%)
# updating: content/linear/SVHN/e2e_ff.csv (stored 0%)
# updating: content/attention/ (stored 0%)
# updating: content/attention/FashionMNIST/ (stored 0%)
# updating: content/attention/FashionMNIST/gpu_compute_attention_ff.csv (deflated 62%)
# updating: content/attention/FashionMNIST/epoch_linear_ff.csv (deflated 57%)
# updating: content/attention/FashionMNIST/nvidia_smi.csv (deflated 88%)
# updating: content/attention/FashionMNIST/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/attention/FashionMNIST/layer_ff.csv (deflated 7%)
# updating: content/attention/FashionMNIST/epoch_attention_ff.csv (deflated 53%)
# updating: content/attention/FashionMNIST/e2e_ff.csv (stored 0%)
# updating: content/attention/CIFAR10/ (stored 0%)
# updating: content/attention/CIFAR10/gpu_compute_attention_ff.csv (deflated 63%)
# updating: content/attention/CIFAR10/epoch_linear_ff.csv (deflated 57%)
# updating: content/attention/CIFAR10/nvidia_smi.csv (deflated 88%)
# updating: content/attention/CIFAR10/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/attention/CIFAR10/layer_ff.csv (deflated 12%)
# updating: content/attention/CIFAR10/epoch_attention_ff.csv (deflated 53%)
# updating: content/attention/CIFAR10/e2e_ff.csv (stored 0%)
# updating: content/attention/CIFAR100/ (stored 0%)
# updating: content/attention/CIFAR100/gpu_compute_attention_ff.csv (deflated 63%)
# updating: content/attention/CIFAR100/epoch_linear_ff.csv (deflated 58%)
# updating: content/attention/CIFAR100/nvidia_smi.csv (deflated 87%)
# updating: content/attention/CIFAR100/gpu_compute_linear_ff.csv (deflated 62%)
# updating: content/attention/CIFAR100/layer_ff.csv (deflated 9%)
# updating: content/attention/CIFAR100/epoch_attention_ff.csv (deflated 53%)
# updating: content/attention/CIFAR100/e2e_ff.csv (stored 0%)
#   adding: content/attention/SVHN/ (stored 0%)
#   adding: content/attention/SVHN/gpu_compute_attention_ff.csv (deflated 64%)
#   adding: content/attention/SVHN/epoch_linear_ff.csv (deflated 58%)
#   adding: content/attention/SVHN/nvidia_smi.csv (deflated 87%)
#   adding: content/attention/SVHN/gpu_compute_linear_ff.csv (deflated 63%)
#   adding: content/attention/SVHN/layer_ff.csv (deflated 11%)
#   adding: content/attention/SVHN/epoch_attention_ff.csv (deflated 53%)
#   adding: content/attention/SVHN/e2e_ff.csv (stored 0%)
